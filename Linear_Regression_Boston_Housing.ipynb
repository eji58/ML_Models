# %% [markdown]
# <a href="https://colab.research.google.com/github/eji58/ML_Models/blob/main/Linear_Regression_Boston_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.index
# Out:
# RangeIndex(start=0, stop=506, step=1)

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# 1. CRIM - per capita crime rate by town
# 2. ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS - proportion of non-retail business acres per town.
# 4. CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# 5. NOX - nitric oxides concentration (parts per 10 million)
# 6. RM - average number of rooms per dwelling
# 7. AGE - proportion of owner-occupied units built prior to 1940
# 8. DIS - weighted distances to five Boston employment centres
# 9. RAD - index of accessibility to radial highways
# 10. TAX - full-value property-tax rate per $10,000.
# 11. PTRATIO - pupil-teacher ratio by town.
# 12. B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# 13. LSTAT - % lower status of the population.
# 14. MEDV - Median value of owner-occupied homes in $1000's.

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.nunique()
# Out:
# crim       504
# zn          26
# indus       76
# chas         2
# nox         81
# rm         446
# age        356
# dis        412
# rad          9
# tax         66
# ptratio     46
# b          357
# lstat      455
# medv       229
# dtype: int64

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# sns.pairplot(df)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f13ea_row0_col0, #T_f13ea_row1_col1, #T_f13ea_row2_col2, #T_f13ea_row3_col3, #T_f13ea_row4_col4, #T_f13ea_row5_col5, #T_f13ea_row6_col6, #T_f13ea_row7_col7, #T_f13ea_row8_col8, #T_f13ea_row9_col9, #T_f13ea_row10_col10, #T_f13ea_row11_col11, #T_f13ea_row12_col12, #T_f13ea_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f13ea_row0_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f13ea_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_f13ea_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_f13ea_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_f13ea_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_f13ea_row0_col6, #T_f13ea_row1_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_f13ea_row0_col7, #T_f13ea_row11_col4, #T_f13ea_row11_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# ...

# %%
def num_drow(col):
  """
  drowing the categorical columns 
  """
  plt.figure(figsize=(10,5))
  # sns.countplot(df[col],hue=df['y'] )
  sns.distplot(df[col])
  plt.title(f'Distribution of {col}')
  plt.show()

# %%
for col in df.columns:
  num_drow(col)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.boxplot(y=k, data=df, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
# remove the outlier from our target column ... MEDV
df=df[~(df['medv']>=50)]
df.shape
# Out:
# (490, 14)

# %%
num_drow('medv')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
X=df.drop(['medv'],axis=1)
y=df[['medv']]

# %%
X.shape, y.shape
# Out:
# ((490, 13), (490, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((392, 13), (98, 13), (392, 1), (98, 1))

# %%
model= LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
val_train = round(model.score(X_train, y_train),2)*100
val_test = round(model.score(X_test, y_test),2)*100

print(f'Training Accuracy: {val_train}%')
print(f'Test Set Accuracy: {val_test}%')
# Out:
# Training Accuracy: 78.0%
# Test Set Accuracy: 76.0%

# %%
y_pred=model.predict(X_test)
print(f'Mean Squared Error(MSE): {mean_absolute_error(y_test, y_pred):.4}')
print(f'Mean Absolute Error(MAE): {mean_squared_error(y_test, y_pred):.4}')
# Out:
# Mean Squared Error(MSE): 3.137
# Mean Absolute Error(MAE): 18.74

# %%
df.to_csv("BostonHousing.csv")
